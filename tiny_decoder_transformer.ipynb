# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.2
# ------------

torch.manual_seed(1337)

#!wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
#!wget https://raw.githubusercontent.com/anirudhshenoy/text-classification-small-datasets/master/datasets/clickbait_data
with open('clickbait_data', 'r', encoding='utf-8') as f:
    text = f.read()

print("length of dataset in characters: ", len(text))

print("First 1000 characters :", text[:1000])
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters()), ' parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# length of dataset in characters:  923965
# First 1000 characters : Should I Get Bings
#
# Which TV Female Friend Group Do You Belong In
#
# The New "Star Wars: The Force Awakens" Trailer Is Here To Give You Chills
#
# This Vine Of New York On "Celebrity Big Brother" Is Fucking Perfect
#
# A Couple Did A Stunning Photo Shoot With Their Baby After Learning She Had An Inoperable Brain Tumor
#
# How To Flirt With Queer Girls Without Making A Total Fool Of Yourself
#
# 32 Cute Things To Distract From Your Awkward Thanksgiving
#
# If Disney Princesses Were From Florida
#
# What's A Quote Or Lyric That Best Describes Your Depression
#
# Natalie Dormer And Sam Claflin Play A Game To See How They'd Actually Last In "The Hunger Games"
#
# 16 Perfect Responses To The Indian Patriarchy
#
# 21 Times I Died During The "Captain America: Civil War" Teaser
#
# 17 Times Kourtney Kardashian Shut Down Her Own Family
#
# Does Coffee Make You Poop
#
# Who Is Your Celebrity Ex Based On Your Zodiac
#
# 17 Hairdresser Struggles Every Black Girl Knows To Be True
#
# Are You More Walter White Or Heisenberg
#
# The Most Canadian
# 227032  parameters
# step 0: train loss 4.6409, val loss 4.6404
# step 100: train loss 2.5362, val loss 2.5334
# step 200: train loss 2.4040, val loss 2.4027
# step 300: train loss 2.3694, val loss 2.3688
# step 400: train loss 2.3435, val loss 2.3433
# step 500: train loss 2.3219, val loss 2.3212
# step 600: train loss 2.2959, val loss 2.2941
# step 700: train loss 2.2703, val loss 2.2688
# step 800: train loss 2.2416, val loss 2.2387
# step 900: train loss 2.2044, val loss 2.2042
# step 1000: train loss 2.1689, val loss 2.1662
# step 1100: train loss 2.1295, val loss 2.1267
# step 1200: train loss 2.0942, val loss 2.0909
# step 1300: train loss 2.0541, val loss 2.0513
# step 1400: train loss 2.0243, val loss 2.0233
# step 1500: train loss 1.9934, val loss 1.9933
# step 1600: train loss 1.9694, val loss 1.9673
# step 1700: train loss 1.9400, val loss 1.9330
# step 1800: train loss 1.9156, val loss 1.9116
# step 1900: train loss 1.8938, val loss 1.8917
# step 2000: train loss 1.8738, val loss 1.8706
# step 2100: train loss 1.8509, val loss 1.8458
# step 2200: train loss 1.8316, val loss 1.8295
# step 2300: train loss 1.8137, val loss 1.8074
# step 2400: train loss 1.8002, val loss 1.7931
# step 2500: train loss 1.7841, val loss 1.7827
# step 2600: train loss 1.7674, val loss 1.7661
# step 2700: train loss 1.7528, val loss 1.7500
# step 2800: train loss 1.7385, val loss 1.7348
# step 2900: train loss 1.7264, val loss 1.7189
# step 3000: train loss 1.7093, val loss 1.7103
# step 3100: train loss 1.7026, val loss 1.6997
# step 3200: train loss 1.6919, val loss 1.6860
# step 3300: train loss 1.6800, val loss 1.6809
# step 3400: train loss 1.6712, val loss 1.6712
# step 3500: train loss 1.6593, val loss 1.6599
# step 3600: train loss 1.6469, val loss 1.6484
# step 3700: train loss 1.6423, val loss 1.6392
# step 3800: train loss 1.6357, val loss 1.6345
# step 3900: train loss 1.6266, val loss 1.6245
# step 4000: train loss 1.6206, val loss 1.6152
# step 4100: train loss 1.6077, val loss 1.6119
# step 4200: train loss 1.6007, val loss 1.6012
# step 4300: train loss 1.5933, val loss 1.5923
# step 4400: train loss 1.5854, val loss 1.5850
# step 4500: train loss 1.5829, val loss 1.5864
# step 4600: train loss 1.5765, val loss 1.5798
# step 4700: train loss 1.5730, val loss 1.5719
# step 4800: train loss 1.5685, val loss 1.5706
# step 4900: train loss 1.5569, val loss 1.5586
# step 5000: train loss 1.5505, val loss 1.5545
# step 5100: train loss 1.5452, val loss 1.5523
# step 5200: train loss 1.5425, val loss 1.5472
# step 5300: train loss 1.5373, val loss 1.5341
# step 5400: train loss 1.5331, val loss 1.5396
# step 5500: train loss 1.5276, val loss 1.5305
# step 5600: train loss 1.5255, val loss 1.5255
# step 5700: train loss 1.5189, val loss 1.5215
# step 5800: train loss 1.5077, val loss 1.5147
# step 5900: train loss 1.5068, val loss 1.5118
# step 6000: train loss 1.5041, val loss 1.5092
# step 6100: train loss 1.4973, val loss 1.5070
# step 6200: train loss 1.4968, val loss 1.5040
# step 6300: train loss 1.4832, val loss 1.4962
# step 6400: train loss 1.4840, val loss 1.4925
# step 6500: train loss 1.4839, val loss 1.4884
# step 6600: train loss 1.4747, val loss 1.4852
# step 6700: train loss 1.4725, val loss 1.4824
# step 6800: train loss 1.4694, val loss 1.4730
# step 6900: train loss 1.4651, val loss 1.4726
# step 7000: train loss 1.4565, val loss 1.4710
# step 7100: train loss 1.4589, val loss 1.4636
# step 7200: train loss 1.4554, val loss 1.4623
# step 7300: train loss 1.4457, val loss 1.4602
# step 7400: train loss 1.4473, val loss 1.4575
# step 7500: train loss 1.4441, val loss 1.4597
# step 7600: train loss 1.4381, val loss 1.4499
# step 7700: train loss 1.4321, val loss 1.4442
# step 7800: train loss 1.4319, val loss 1.4371
# step 7900: train loss 1.4289, val loss 1.4378
# step 8000: train loss 1.4243, val loss 1.4358
# step 8100: train loss 1.4241, val loss 1.4355
# step 8200: train loss 1.4205, val loss 1.4308
# step 8300: train loss 1.4184, val loss 1.4286
# step 8400: train loss 1.4155, val loss 1.4271
# step 8500: train loss 1.4087, val loss 1.4224
# step 8600: train loss 1.4088, val loss 1.4186
# step 8700: train loss 1.4045, val loss 1.4197
# step 8800: train loss 1.4014, val loss 1.4188
# step 8900: train loss 1.4048, val loss 1.4155
# step 9000: train loss 1.3949, val loss 1.4110
# step 9100: train loss 1.3970, val loss 1.4079
# step 9200: train loss 1.3910, val loss 1.4039
# step 9300: train loss 1.3883, val loss 1.4050
# step 9400: train loss 1.3895, val loss 1.4062
# step 9500: train loss 1.3835, val loss 1.4017
# step 9600: train loss 1.3906, val loss 1.4006
# step 9700: train loss 1.3811, val loss 1.3966
# step 9800: train loss 1.3824, val loss 1.3977
# step 9900: train loss 1.3788, val loss 1.3933
# step 9999: train loss 1.3739, val loss 1.3881
#
# 42 Storics Sea Ealls Prived To Want
#
# Taylor Hallowen Cases If Wey To Reciped Is Your Life All Awkted
#
# Cart You Guess That Pintere No Benutflines Or Mady
#
# 30 Women Don't K This "Hary Lover In Like TV Question
#
# The Most Questic Most For Phone If Music Ofre Thorey
#
# Which Beased A Boddy
#
# 17 Hason-Amy Addorable Burg Phontanin's Show Not Groum"
#
# 17 Mostromans Irismately Sik Fakoold Pys On One Unboberaque Reascal Will Phe Cologhen Fister
#
# 25 Hillarious The Most Prosonans Are Old Adorably Can't Trey
#
# Can You Gueend The First Maving Posteni" Rightmaras
#
# Couple Are If You Boy Craick For This Predict Lover-Traken Ween To Finy Bugg Based Our Game In Instagrant
#
# 59 People Who Woman You Gese Your Stroot Seep, Based Onse Are You
#
# Tina
#
# Aid Ampletora Harry On Hannsg Terrifyind Women In Alll Make Onling Gase On
#
# Kim No Is These Collate Guy Pernesphire Fanaio A Lucked
#
# And These Costurent Deffining Outher Some
#
# 23 Diffines Hadn Teen Wedddin's New To Celebritie Dastack
#
# 89 Beautl Will Nevall
#
# You Watch Your Hadppends" Bease For Act About 5 Say
#
# 15 Startorial Why Kerend Is To Be Feart Get'$50-Momentstantlatives
#
# What Bragaced Are You Artie Insagram Will Tage A Trating
#
# Can You Neer
# Weatch Hough I2015,0 Girl Mumbas An Starbian Food Your Like Anfica
#
# 22 Cutesy To Grues AF YLoona Wik Oflet Timble Dog Wreats
#
# Tell Georynen Cap
#
# 17 Pract Reall Masic Increades To Remine Way Delichia Fallowood Off Just Reactic Movion
#
# Are You Morte Zac Alal Prigeon Out Will Make You Pas
#
# That Will Passon Of Before An Managlennd Covedived Ro In 20ations Photos Ever An't Didne You'll Swreak
#
# 29 Garaner-You God To Be Or Try
#
# 21 Women You Know In 2015 That Cat Of By Shaving Don't And It's Woman
#
# 29 Belack A Mentings Joking Just Of There Secorep
#
# 18 Of The Accogns Of Betfemore Lody Boooks To Luckiking A Stens In Mormesants
#
# The Fro
#
# What Newood In Your Based On Quotions Can You Un About Zodiac Foods Of When Yourk For Them Adddiann Was The Host Alecac Scett Foreak
#
# Ameha Is Way Totatle Sting Suffts You Agared Tok C
